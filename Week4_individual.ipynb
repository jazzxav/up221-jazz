# %% [markdown]
# # Race and Household with vehicle

# %%
import pandas as pd

# %%
# load a data file
# note the relative filepath! where is this file located?
df = pd.read_csv(
    'Data/R13572491_SL140.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    }
)

# %%
df.shape
# Out:
# (5, 112)

# %%
df.head()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_STUSAB  \
# 0  06037206302  Census Tract 2063.02, Los Angeles County, Cali...         ca
# 1  06037206303  Census Tract 2063.03, Los Angeles County, Cali...         ca
# 2  06037208903  Census Tract 2089.03, Los Angeles County, Cali...         ca
# 3  06037209401  Census Tract 2094.01, Los Angeles County, Cali...         ca
# 4  06037209402  Census Tract 2094.02, Los Angeles County, Cali...         ca
#
#    Geo_SUMLEV  Geo_GEOCOMP  Geo_US  Geo_REGION  Geo_DIVISION Geo_STATE  \
# 0         140            0     NaN         NaN           NaN        06
# 1         140            0     NaN         NaN           NaN        06
# 2         140            0     NaN         NaN           NaN        06
# 3         140            0     NaN         NaN           NaN        06
# 4         140            0     NaN         NaN           NaN        06
#
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.sample()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_STUSAB  \
# 2  06037208903  Census Tract 2089.03, Los Angeles County, Cali...         ca
#
#    Geo_SUMLEV  Geo_GEOCOMP  Geo_US  Geo_REGION  Geo_DIVISION Geo_STATE  \
# 2         140            0     NaN         NaN           NaN        06
#
#   Geo_COUNTY  Geo_COUSUB  Geo_PLACE  Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  \
# 2        037         NaN        NaN     208903         NaN         NaN
#
#    Geo_AIANHH  Geo_AIANHHFP  Geo_AIHHTLI  Geo_AITS  Geo_ANRC  Geo_CBSA  \
# 2         NaN           NaN          NaN       NaN       NaN       NaN
#
#    Geo_CSA  Geo_METDIV  Geo_MACC  Geo_MEMI  Geo_NECTA  Geo_CNECTA  \
# 2      NaN         NaN       NaN       NaN        NaN         NaN
#
#    Geo_NECTADIV  Geo_UA  Geo_CDCURR  Geo_SLDU  Geo_SLDL  Geo_ZCTA3  Geo_ZCTA5  \
# 2           NaN     NaN         NaN       NaN       NaN        NaN        NaN
#
# ...

# %%
# data looks good
# look at the data types, verbose = True shows us all the counts
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 112 columns):
#  #    Column             Non-Null Count  Dtype
# ---   ------             --------------  -----
#  0    Geo_FIPS           5 non-null      object
#  1    Geo_QName          5 non-null      object
#  2    Geo_STUSAB         5 non-null      object
#  3    Geo_SUMLEV         5 non-null      int64
#  4    Geo_GEOCOMP        5 non-null      int64
#  5    Geo_US             0 non-null      float64
#  6    Geo_REGION         0 non-null      float64
#  7    Geo_DIVISION       0 non-null      float64
#  8    Geo_STATE          5 non-null      object
#  9    Geo_COUNTY         5 non-null      object
#  10   Geo_COUSUB         0 non-null      float64
#  11   Geo_PLACE          0 non-null      float64
#  12   Geo_TRACT          5 non-null      int64
#  13   Geo_BLKGRP         0 non-null      float64
#  14   Geo_CONCIT         0 non-null      float64
# ...

# %%
#no leading zero issue
df.Geo_FIPS.head()
# Out:
# 0    06037206302
# 1    06037206303
# 2    06037208903
# 3    06037209401
# 4    06037209402
# Name: Geo_FIPS, dtype: object

# %% [markdown]
# # Data Sorting

# %%
df.columns[df.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_PUMA5',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PLACESE']

# %%
# axis = 0 drops rows axis = 1 drops columns with null
df = df.dropna(axis=1,how="all")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 76 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           5 non-null      object
#  1   Geo_QName          5 non-null      object
#  2   Geo_STUSAB         5 non-null      object
#  3   Geo_SUMLEV         5 non-null      int64
#  4   Geo_GEOCOMP        5 non-null      int64
#  5   Geo_STATE          5 non-null      object
#  6   Geo_COUNTY         5 non-null      object
#  7   Geo_TRACT          5 non-null      int64
#  8   Geo_NAME           5 non-null      object
#  9   SE_A03001_001      5 non-null      int64
#  10  SE_A03001_002      5 non-null      int64
#  11  SE_A03001_003      5 non-null      int64
#  12  SE_A03001_004      5 non-null      int64
#  13  SE_A03001_005      5 non-null      int64
#  14  SE_A03001_006      5 non-null      int64
#  15  SE_A03001_007      5 non-null      int64
# ...

# %%
 # reinspect the data
df.head()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_STUSAB  \
# 0  06037206302  Census Tract 2063.02, Los Angeles County, Cali...         ca
# 1  06037206303  Census Tract 2063.03, Los Angeles County, Cali...         ca
# 2  06037208903  Census Tract 2089.03, Los Angeles County, Cali...         ca
# 3  06037209401  Census Tract 2094.01, Los Angeles County, Cali...         ca
# 4  06037209402  Census Tract 2094.02, Los Angeles County, Cali...         ca
#
#    Geo_SUMLEV  Geo_GEOCOMP Geo_STATE Geo_COUNTY  Geo_TRACT  \
# 0         140            0        06        037     206302
# 1         140            0        06        037     206303
# 2         140            0        06        037     208903
# 3         140            0        06        037     209401
# 4         140            0        06        037     209402
#
#                Geo_NAME  SE_A03001_001  SE_A03001_002  SE_A03001_003  \
# 0  Census Tract 2063.02           2271            527           1020
# ...

# %%
#now we keep the important columns
columns_to_keep = ['Geo_FIPS',
                   'SE_A03001_001',
                   'SE_A03001_002',
                   'SE_A03001_003',
                   'SE_A03001_004',
                   'SE_A03001_005',
                   'SE_A03001_006',
                   'SE_A03001_007',
                   'SE_A03001_008',
                  'SE_A09005_001',
                  'SE_A09005_002',
                  'SE_A09005_009',
                  'SE_A09005_010',
                  'SE_A09005_003',
                  'SE_A09005_004',
                  'SE_A09005_005',
                  'SE_A09005_006',
                  'SE_A09005_007',
                  'SE_A09005_008']
# add it to a new dataframe
df2 = df[columns_to_keep]

# %%
df2.columns = ['FIPS', 
'TotalPop',
'White Alone',
'Black or African American Alone',
'American Indian and Alaska Native Alone',
'Asian Alone',
'Native Hawaiian and Other Pacific Islander Alone',
'Some Other Race Alone',
'Two or More Races',
'Workers 16 Years and Over',
'Car, Truck, or Van',
'Drove Alone',
'Carpooled',
'Public Transportation (Includes Taxicab)',
'Motorcycle',
'Bicycle',
'Walked',
'Other Means',
'Worked At Home']

# %%
df2.sample(5)
# Out:
#           FIPS  TotalPop  White Alone  Black or African American Alone  \
# 2  06037208903      3955          861                              276
# 4  06037209402      4296         1215                               58
# 1  06037206303      2757          717                             1246
# 0  06037206302      2271          527                             1020
# 3  06037209401      4095         1310                              505
#
#    American Indian and Alaska Native Alone  Asian Alone  \
# 2                                      168          160
# 4                                       86          197
# 1                                      106           91
# 0                                       89           38
# 3                                       25          523
#
#    Native Hawaiian and Other Pacific Islander Alone  Some Other Race Alone  \
# 2                                                 0                   2318
# ...

# %% [markdown]
# # Graphs

# %%
df2.plot.barh(x='FIPS',
                            y='White Alone',
                            title='White Population Across Census Tracts',
                            color='orange')
# Out:
# <Axes: title={'center': 'White Population Across Census Tracts'}, ylabel='FIPS'>

# %%
df2.plot.barh(x='FIPS',
                            y='Black or African American Alone',
                            title='Black Population Across Census Tracts',
                            color='red')
# Out:
# <Axes: title={'center': 'Black Population Across Census Tracts'}, ylabel='FIPS'>

# %%
df2.plot.barh(x='FIPS',
                            y='Car, Truck, or Van',
                            title='Count of Population That Takes Car, Truck, or Van Across Census Tracts',
                            color='green')
# Out:
# <Axes: title={'center': 'Count of Population That Takes Car, Truck, or Van Across Census Tracts'}, ylabel='FIPS'>

# %%
df2.plot.barh(x='FIPS',
                            y='Public Transportation (Includes Taxicab)',
                            title='Count of Population That Takes Public Transit(including taxicabs) Across Census Tracts',
                            color='purple')
# Out:
# <Axes: title={'center': 'Count of Population That Takes Public Transit(including taxicabs) Across Census Tracts'}, ylabel='FIPS'>

# %% [markdown]
# # MAPS

# %%
import geopandas as gpd

# %%
# read in a geojson file downloaded from the LA Times
tracts=gpd.read_file('Data/Census_Tracts_2020.geojson')
tracts.head()
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0         1  101110  1011.10  1.229562e+07   15083.854287
# 1         2  101122  1011.22  2.845774e+07   31671.455844
# 2         3  101220  1012.20  7.522093e+06   12698.783810
# 3         4  101221  1012.21  3.812000e+06    9161.710543
# 4         5  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry
# 0  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
#plot it
tracts.plot(figsize=(12,10))
# Out:
# <Axes: >

# %%
# we only really need FIPS and geometry, so let's subset the data
tracts = tracts[['CT20','geometry']]
tracts.head()
# Out:
#      CT20                                           geometry
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
# create a FIPS column
tracts['FIPS'] ='06' + '037' + tracts['CT20']
# Out:
# /opt/conda/lib/python3.11/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# check it!
tracts.head()
# Out:
#      CT20                                           geometry         FIPS
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...  06037101110
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...  06037101122
# 2  101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...  06037101220
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...  06037101222

# %%
# create a new dataframe based on the join
tracts_raceandtranstype=tracts.merge(df2,on="FIPS")

# %%
tracts_raceandtranstype.head()
# Out:
#      CT20                                           geometry         FIPS  \
# 0  206302  POLYGON ((-118.24550 34.04193, -118.24525 34.0...  06037206302
# 1  206303  POLYGON ((-118.24049 34.04210, -118.24123 34.0...  06037206303
# 2  208903  POLYGON ((-118.27186 34.05934, -118.27131 34.0...  06037208903
# 3  209401  POLYGON ((-118.27975 34.05411, -118.27961 34.0...  06037209401
# 4  209402  POLYGON ((-118.27558 34.05387, -118.27456 34.0...  06037209402
#
#    TotalPop  White Alone  Black or African American Alone  \
# 0      2271          527                             1020
# 1      2757          717                             1246
# 2      3955          861                              276
# 3      4095         1310                              505
# 4      4296         1215                               58
#
#    American Indian and Alaska Native Alone  Asian Alone  \
# 0                                       89           38
# ...

# %%
tracts_raceandtranstype.plot(figsize=(12,10),
                 column='White Alone',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
tracts_raceandtranstype.plot(figsize=(12,10),
                 column='Black or African American Alone',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# lets look at majority ethnic cluster in LA
# First, create new columns for percentages
tracts_raceandtranstype['PCT_Black'] = tracts_raceandtranstype['Black or African American Alone']/tracts_raceandtranstype['TotalPop']*100
tracts_raceandtranstype['PCT_White'] = tracts_raceandtranstype['White Alone']/tracts_raceandtranstype['TotalPop']*100
tracts_raceandtranstype['PCT_Asian'] = tracts_raceandtranstype['Asian Alone']/tracts_raceandtranstype['TotalPop']*100

# %%
tracts_raceandtranstype.plot(figsize=(12,10),
                 column='PCT_Black',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <Axes: >

# %%
tracts_raceandtranstype[tracts_raceandtranstype.PCT_Asian > 5].plot(figsize=(12,10))
# Out:
# <Axes: >

# %%
#now lets import the folium to make the cool interactive map
import folium

# %%
m = folium.Map(location=[34.2,-118.2], 
               zoom_start = 10,
               tiles='CartoDB positron', 
               attribution='CartoDB')

# plot chorpleth over the base map
folium.Choropleth(
                  geo_data=tracts_raceandtranstype, # geo data
                  data=tracts_raceandtranstype, # data          
                  key_on='feature.properties.FIPS', # key, or merge column
                  columns=['FIPS', 'PCT_White'], # [key, value]
                  fill_color='BuPu',
                  line_weight=0.1, 
                  fill_opacity=0.8,
                  line_opacity=0.2, # line opacity (of the border)
                  legend_name='Percent Population White For Tracts With Highest Public Transit Commute (2022)').add_to(m)    # name on the legend color bar
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location=[34.2,-118.2], 
               zoom_start = 10,
               tiles='CartoDB positron', 
               attribution='CartoDB')

# plot chorpleth over the base map
folium.Choropleth(
                  geo_data=tracts_raceandtranstype, # geo data
                  data=tracts_raceandtranstype, # data          
                  key_on='feature.properties.FIPS', # key, or merge column
                  columns=['FIPS', 'PCT_Asian'], # [key, value]
                  fill_color='BuPu',
                  line_weight=0.1, 
                  fill_opacity=0.8,
                  line_opacity=0.2, # line opacity (of the border)
                  legend_name='Percent Population White For Tracts With Highest Public Transit Commute (2022)').add_to(m)    # name on the legend color bar
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
